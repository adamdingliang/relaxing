# %%
# %matplotlib inline
#!/usr/bin/env python3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
intake_df = pd.read_csv('intake.csv', sep='\t')
intake_df.head()
# Out:
#   anls_type_name anls_run_name        formal_name            target_name  \
# 0         intake      j5PYhAMm  SJMMNORM054925_C1    CHIPSEQ_H3K27Ac-AB2
# 1         intake      j5PYhAMm  SJMMNORM054925_C1   CHIPSEQ_H3K36me3-AB2
# 2         intake      j5PYhAMm  SJMMNORM054925_C1    CHIPSEQ_H3K4me1-AB2
# 3         intake      j5PYhAMm  SJMMNORM054925_C1  CHIPSEQ_H3K9-14Ac-AB3
# 4         intake      j5PYhAMm  SJMMNORM054925_C1    CHIPSEQ_H3K9me3-AB2
#
#   project_name subproject   genome                  begin_date  \
# 0         Dyer       Dyer  MGSCv37  2018-01-05 19:10:46.595741
# 1         Dyer       Dyer  MGSCv37  2018-01-05 19:10:46.595741
# 2         Dyer       Dyer  MGSCv37  2018-01-05 19:10:46.595741
# 3         Dyer       Dyer  MGSCv37  2018-01-05 19:10:46.595741
# 4         Dyer       Dyer  MGSCv37  2018-01-05 19:10:46.595741
#
#                      end_date    duration
# 0  2018-01-05 19:17:58.551347  431.955606
# 1  2018-01-05 19:17:58.551347  431.955606
# 2  2018-01-05 19:17:58.551347  431.955606
# 3  2018-01-05 19:17:58.551347  431.955606
# 4  2018-01-05 19:17:58.551347  431.955606

# %%
new_target_names = []
for target in intake_df['target_name']:
    if target[0:8] =='CHIPSEQ_':
        new_target_names.append('CHIPSEQ')
    else:
        new_target_names.append(target)
len(new_target_names)
# Out:
# 36592

# %%
temp_df = pd.DataFrame({'target_name': new_target_names})
intake_df.update(temp_df)
intake_df.head()
# Out:
#   anls_type_name anls_run_name        formal_name target_name project_name  \
# 0         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 1         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 2         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 3         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 4         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
#
#   subproject   genome                  begin_date                    end_date  \
# 0       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 1       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 2       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 3       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 4       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
#
#      duration
# 0  431.955606
# 1  431.955606
# 2  431.955606
# 3  431.955606
# 4  431.955606

# %%
chip_df = intake_df[intake_df['target_name'] == 'CHIPSEQ']
chip_df.head()
# Out:
#   anls_type_name anls_run_name        formal_name target_name project_name  \
# 0         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 1         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 2         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 3         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
# 4         intake      j5PYhAMm  SJMMNORM054925_C1     CHIPSEQ         Dyer
#
#   subproject   genome                  begin_date                    end_date  \
# 0       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 1       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 2       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 3       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
# 4       Dyer  MGSCv37  2018-01-05 19:10:46.595741  2018-01-05 19:17:58.551347
#
#      duration
# 0  431.955606
# 1  431.955606
# 2  431.955606
# 3  431.955606
# 4  431.955606

# %%
chip_bd_df = chip_df.groupby(['begin_date']).mean()

# %%
sorted_chip_bd_df = chip_bd_df.sort_index(level=1)
sorted_chip_bd_df.head()
# Out:
#                                 duration
# begin_date
# 2015-07-28 17:09:18.766069  79158.553545
# 2015-07-28 17:09:22.247958  71500.004569
# 2015-07-29 15:58:58.695744   1000.882389
# 2015-07-29 15:59:28.317944   1414.362752
# 2015-07-30 15:11:19.945059    438.563781

# %%
# Select last few rows
sorted_chip_no_outlier_df = sorted_chip_no_outlier_df.iloc[range(300, sorted_chip_no_outlier_df.shape[0])]
# Out:
#                                 duration  outlier
# begin_date
# 2017-08-03 19:16:21.358801    405.654056    False
# 2017-08-13 22:50:31.541622   2699.265964    False
# 2017-08-19 19:11:28.256847   2668.101672    False
# 2017-09-01 19:10:46.946566    755.086356    False
# 2017-09-06 15:03:58.356994   2050.754860    False
# 2017-09-06 15:16:23.394111    807.355852    False
# 2017-09-06 15:17:56.895195    638.342511    False
# 2017-09-06 16:00:05.107222    305.506731    False
# 2017-09-06 16:00:14.013083    322.842315    False
# 2017-09-06 16:00:23.115194   1827.216688    False
# 2017-09-06 16:00:32.878448   1354.669567    False
# 2017-09-06 16:00:40.756445   1603.060797    False
# 2017-09-06 16:00:46.161021    966.014630    False
# 2017-09-06 16:00:50.507216    972.996749    False
# 2017-09-06 16:00:54.458590    315.397979    False
# 2017-09-06 16:00:58.053431   1520.245703    False
# 2017-09-08 19:05:44.176463  40303.406233    False
# 2017-09-08 19:06:12.083404  44022.765596    False
# 2017-09-22 19:05:08.096382   8785.524254    False
# 2017-09-22 19:05:35.636574   8950.994463    False
# 2017-09-22 19:06:05.190487   9230.653443    False
# 2017-09-29 19:05:53.050382    508.206270    False
# 2017-09-29 19:06:05.380881    204.500014    False
# 2017-09-29 19:06:46.005529    461.415956    False
# 2017-10-03 19:04:50.460489    273.343502    False
# 2017-10-03 19:06:24.986264    810.446299    False
# 2017-10-03 19:08:30.064761    747.539694    False
# 2017-10-03 19:08:48.809810   1584.925894    False
# 2017-10-05 19:07:17.710986   3697.861025    False
# 2017-10-28 19:09:41.953835    500.506388    False
# ...                                  ...      ...
# 2017-10-30 19:12:52.031660   1308.182274    False
# 2017-10-30 19:13:08.296996    393.532005    False
# 2017-12-04 19:09:28.215353   1055.080031    False
# 2017-12-04 19:09:51.180192    913.819645    False
# 2017-12-04 19:10:14.803833    956.936999    False
# 2017-12-04 19:10:38.719993    940.422910    False
# 2017-12-04 19:10:58.380664    610.452748    False
# 2017-12-04 19:11:17.920456    829.650041    False
# 2017-12-04 19:11:36.982345    818.038927    False
# 2017-12-06 19:09:44.627225    451.441735    False
# 2017-12-06 19:09:54.796178    380.273362    False
# 2017-12-06 19:10:03.986733    378.843267    False
# 2017-12-06 19:10:14.692456    377.839412    False
# 2017-12-07 19:10:03.325212    497.582691    False
# 2017-12-08 19:09:51.093958    511.343429    False
# 2017-12-08 19:10:12.745536    565.302627    False
# 2017-12-12 19:09:34.039998    135.039995    False
# 2017-12-12 19:09:46.109902    143.479304    False
# 2018-01-02 19:11:33.834490    986.205822    False
# 2018-01-02 19:11:46.636248    984.106876    False
# 2018-01-02 19:11:56.744517    134.004557    False
# 2018-01-02 19:12:05.606867    134.486760    False
# 2018-01-02 19:12:15.222033    920.363721    False
# 2018-01-02 19:12:28.024487    204.927483    False
# 2018-01-02 19:12:41.238749    383.728792    False
# 2018-01-02 19:12:50.452322    133.584262    False
# 2018-01-02 19:12:58.039759    133.885483    False
# 2018-01-02 19:13:08.051847    375.246346    False
# 2018-01-05 19:10:09.494994    193.854720    False
# 2018-01-05 19:10:46.595741    431.955606    False
#
# [62 rows x 2 columns]

# %%
print('std: ' + str(sorted_chip_bd_df['duration'].std()))
sorted_chip_bd_df['outlier'] = abs(sorted_chip_bd_df['duration'] - sorted_chip_bd_df['duration'].mean()) > 1.96 * sorted_chip_bd_df['duration'].std()
sorted_chip_no_outlier_df = sorted_chip_bd_df[sorted_chip_bd_df['outlier'] == False]
sorted_chip_no_outlier_df.tail()
# Out:
# std: 105872.05381940334
#                               duration  outlier
# begin_date
# 2018-01-02 19:12:50.452322  133.584262    False
# 2018-01-02 19:12:58.039759  133.885483    False
# 2018-01-02 19:13:08.051847  375.246346    False
# 2018-01-05 19:10:09.494994  193.854720    False
# 2018-01-05 19:10:46.595741  431.955606    False

# %%
sorted_chip_no_outlier_df['duration'].plot()
